jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (414).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (416).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1300).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (871).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1543).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1088).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (174).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (207).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (179).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1533).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (359).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (766).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (415).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1124).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (876).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1410).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (971).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (136).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (810).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1331).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1029).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (215).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (692).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (346).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (320).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1013).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (478).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (591).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (534).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1262).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1218).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1204).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (710).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (431).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (918).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (886).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (472).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (701).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (60).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (548).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (441).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1479).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (866).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1496).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (844).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1560).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (607).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (172).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1032).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1342).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (833).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (53).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1492).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (260).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (825).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1530).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (457).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (952).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1126).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1352).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1079).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (974).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1482).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1517).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (630).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1329).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (941).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (855).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (552).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1431).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1285).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1426).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1062).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (729).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (413).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (333).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1276).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (19).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (532).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (703).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1370).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1451).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (369).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (395).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (827).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (104).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (823).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (745).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (515).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1442).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (986).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1257).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (811).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (807).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (628).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1084).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1542).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (9).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1206).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (697).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (663).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (462).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (731).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (961).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (80).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (514).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1309).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (761).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1569).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (81).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (820).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (305).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (818).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (543).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (225).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (224).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (223).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (164).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (848).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1536).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (639).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1311).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1194).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (1186).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (377).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (959).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (882).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (920).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (863).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (465).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Normal/Normal (360).jpg
# ...
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (865).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (266).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1539).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (954).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (472).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (405).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (489).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (339).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1599).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (45).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1227).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1219).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (944).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1449).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (362).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (11).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (394).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1565).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1364).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (870).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1175).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1532).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1435).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (838).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (914).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (609).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1060).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (784).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1235).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (196).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1063).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (301).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1575).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1056).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1236).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (727).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1260).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1131).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (991).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (704).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (755).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (70).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (919).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (904).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (650).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (208).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1222).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1480).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (737).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (456).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (60).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (841).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1314).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (478).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (821).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (483).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (318).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (241).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (594).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (59).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1536).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1464).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (747).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (730).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1567).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (234).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (545).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (286).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (132).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (817).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (933).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1124).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1402).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1515).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (138).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (278).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1096).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (399).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1045).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (753).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (968).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (886).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (525).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (861).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (409).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (21).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1534).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1165).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (42).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (295).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (595).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1077).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (572).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (290).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (888).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1080).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (205).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1050).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (542).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (354).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (118).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (102).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (421).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1366).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1598).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (961).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (197).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (973).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1226).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1543).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (262).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (68).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1475).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1506).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (749).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1563).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (756).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (720).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (721).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1346).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (716).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1211).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (890).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (949).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (957).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (535).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1535).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (864).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (176).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (359).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (947).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (444).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1057).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (420).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1188).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (213).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1026).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1073).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1206).jpg
# /kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Bacterial/Pneumonia-Bacterial (1217).jpg

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.layers import BatchNormalization, Dense, Dropout, Flatten, MaxPool2D, Conv2D, Activation
from IPython.display import clear_output
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pathlib
# necessary libraries
import os

import matplotlib.image as mpimg
from matplotlib.image import imread
# %matplotlib inline

# tensorflow libraries
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras import optimizers

from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array

# model evaluation libraries
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from mlxtend.plotting import plot_confusion_matrix

from glob import glob
from skimage.io import imread
# %matplotlib inline
from pathlib import Path

from keras.applications.resnet import ResNet50
from keras.applications.resnet import preprocess_input, decode_predictions
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import Dense, Dropout, Flatten, BatchNormalization, GlobalMaxPooling2D
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
path=Path('/kaggle/input/3-classification-of-pneumonia/New classification')

# %%
def get_Label(number):
    labels = {


              0 : 'Normal',
              1 : 'Pneumonia-Bacterial',
              2 : 'Pneumonia-Viral'
    }
    return labels[number]

# %%
filepaths=list(path.glob(r'**/*.jpg'))
labels=list(map(lambda x:os.path.split(os.path.split(x)[0])[1],filepaths))
filepaths=pd.Series(filepaths,name='Filepaths').astype(str)
labels=pd.Series(labels,name='Label')
images=pd.concat([filepaths,labels],axis=1)
category_samples=[]

for category in images['Label'].unique():
    category_slices=images.query('Label==@category')
    category_samples.append(category_slices.sample(frac=1,random_state=1))
image_df=pd.concat(category_samples,axis=0).sample(frac=1.0,random_state=1).reset_index(drop=True)

# %%
image_df
# Out:
#                                               Filepaths                Label
# 0     /kaggle/input/3-classification-of-pneumonia/Ne...      Pneumonia-Viral
# 1     /kaggle/input/3-classification-of-pneumonia/Ne...  Pneumonia-Bacterial
# 2     /kaggle/input/3-classification-of-pneumonia/Ne...               Normal
# 3     /kaggle/input/3-classification-of-pneumonia/Ne...      Pneumonia-Viral
# 4     /kaggle/input/3-classification-of-pneumonia/Ne...               Normal
# ...                                                 ...                  ...
# 4833  /kaggle/input/3-classification-of-pneumonia/Ne...      Pneumonia-Viral
# 4834  /kaggle/input/3-classification-of-pneumonia/Ne...      Pneumonia-Viral
# 4835  /kaggle/input/3-classification-of-pneumonia/Ne...               Normal
# 4836  /kaggle/input/3-classification-of-pneumonia/Ne...  Pneumonia-Bacterial
# 4837  /kaggle/input/3-classification-of-pneumonia/Ne...               Normal
#
# [4838 rows x 2 columns]

# %%
image_df['Label'].value_counts()
# Out:
# Label
# Pneumonia-Viral        1638
# Pneumonia-Bacterial    1600
# Normal                 1600
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_df,test_df=train_test_split(image_df,test_size=0.2,random_state=42)

# %%
train_df.shape
# Out:
# (3870, 2)

# %%
test_df.shape
# Out:
# (968, 2)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepaths',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepaths',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepaths',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3096 validated image filenames belonging to 3 classes.
# Found 774 validated image filenames belonging to 3 classes.
# Found 968 validated image filenames belonging to 3 classes.

# %%
pretrained_model=tf.keras.applications.MobileNetV2(
     input_shape=(224,224,3),
     include_top=False,
     weights='imagenet',
     pooling='avg'

)
pretrained_model.trainable=False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
inputs=pretrained_model.input
x=tf.keras.layers.Dense(128,activation='relu')(pretrained_model.output)
x=tf.keras.layers.Dense(128,activation='relu')(x)
outputs=tf.keras.layers.Dense(3,activation='softmax')(x)
model=tf.keras.Model(inputs,outputs)
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']
#  alAveragePooling2D)
#
#  dense_3 (Dense)                (None, 128)          163968      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_4 (Dense)                (None, 128)          16512       ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            387         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 2,438,851
# Trainable params: 180,867
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________
# None

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=15
)
# Out:
# Epoch 1/15
# 97/97 [==============================] - 37s 353ms/step - loss: 0.3636 - accuracy: 0.8385 - val_loss: 0.4008 - val_accuracy: 0.8243
# Epoch 2/15
# 97/97 [==============================] - 33s 343ms/step - loss: 0.3209 - accuracy: 0.8582 - val_loss: 0.5043 - val_accuracy: 0.7674
# Epoch 3/15
# 97/97 [==============================] - 34s 348ms/step - loss: 0.2663 - accuracy: 0.8882 - val_loss: 0.4184 - val_accuracy: 0.8140
# Epoch 4/15
# 97/97 [==============================] - 33s 342ms/step - loss: 0.2594 - accuracy: 0.8963 - val_loss: 0.4148 - val_accuracy: 0.8269
# Epoch 5/15
# 97/97 [==============================] - 33s 343ms/step - loss: 0.2532 - accuracy: 0.8918 - val_loss: 0.4024 - val_accuracy: 0.8411
# Epoch 6/15
# 97/97 [==============================] - 33s 344ms/step - loss: 0.1936 - accuracy: 0.9141 - val_loss: 0.4992 - val_accuracy: 0.8140
# Epoch 7/15
# 97/97 [==============================] - 33s 342ms/step - loss: 0.1490 - accuracy: 0.9399 - val_loss: 0.4524 - val_accuracy: 0.8269
# Epoch 8/15
# 97/97 [==============================] - 33s 344ms/step - loss: 0.1218 - accuracy: 0.9541 - val_loss: 0.5624 - val_accuracy: 0.8230
# Epoch 9/15
# 97/97 [==============================] - 33s 340ms/step - loss: 0.1013 - accuracy: 0.9599 - val_loss: 0.4898 - val_accuracy: 0.8411
# Epoch 10/15
# 97/97 [==============================] - 33s 338ms/step - loss: 0.1373 - accuracy: 0.9454 - val_loss: 0.7482 - val_accuracy: 0.7610
# Epoch 11/15
# 97/97 [==============================] - 33s 344ms/step - loss: 0.0815 - accuracy: 0.9735 - val_loss: 0.5559 - val_accuracy: 0.8307
# Epoch 12/15
# 97/97 [==============================] - 34s 350ms/step - loss: 0.0607 - accuracy: 0.9774 - val_loss: 0.6538 - val_accuracy: 0.8230
# Epoch 13/15
# 97/97 [==============================] - 33s 344ms/step - loss: 0.0401 - accuracy: 0.9877 - val_loss: 0.5946 - val_accuracy: 0.8450
# Epoch 14/15
# 97/97 [==============================] - 37s 386ms/step - loss: 0.0348 - accuracy: 0.9893 - val_loss: 0.6955 - val_accuracy: 0.8359
# Epoch 15/15
# 97/97 [==============================] - 33s 343ms/step - loss: 0.0173 - accuracy: 0.9981 - val_loss: 0.7264 - val_accuracy: 0.8372

# %%
results = model.evaluate(test_images, verbose=0)
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# Test Accuracy: 83.06%

# %%
model.save('MobileNet.h5')

# %%
predictions = np.argmax(model.predict(test_images), axis=1)

cm = confusion_matrix(test_images.labels, predictions)
clr = classification_report(test_images.labels, predictions, target_names=test_images.class_indices, zero_division=0)
# Out:
# 31/31 [==============================] - 10s 305ms/step

# %%
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False)
plt.xticks(ticks=np.arange(3) + 0.5, labels=test_images.class_indices, rotation=90)
plt.yticks(ticks=np.arange(3) + 0.5, labels=test_images.class_indices, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                       precision    recall  f1-score   support
#
#              Normal       0.95      0.97      0.96       322
# Pneumonia-Bacterial       0.76      0.81      0.78       333
#     Pneumonia-Viral       0.78      0.72      0.75       313
#
#            accuracy                           0.83       968
#           macro avg       0.83      0.83      0.83       968
#        weighted avg       0.83      0.83      0.83       968

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
image_path='/kaggle/input/3-classification-of-pneumonia/New classification/Pneumonia-Viral/Pneumonia-Viral (1007).jpg'
img = image.load_img(image_path, target_size=(224,224,3))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.

prediction = model.predict(img_array)
predicted_class_index = np.argmax(prediction)
class_labels = train_images.class_indices
predicted_class_label = list(class_labels.keys())[predicted_class_index]

print('Predicted class:', predicted_class_label)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted class: Pneumonia-Viral
